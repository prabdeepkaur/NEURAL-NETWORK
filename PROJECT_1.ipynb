# %% [markdown]
# <a href="https://colab.research.google.com/github/prabdeepkaur/NEURAL-NETWORK/blob/main/PROJECT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Create a project using logistic regression with tensor?**

# %%
# !pip install pandas scikit-learn tensorflow

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import kagglehub
import os

# %%
path = kagglehub.dataset_download("shubhamgupta012/titanic-dataset")
files = os.listdir(path)

file_path = os.path.join(path, [f for f in files if f.endswith('.csv')][0])
df = pd.read_csv(file_path)

print(df.head())
# Out:
# ...
# 100%|██████████| 6.67k/6.67k [00:00<00:00, 14.5MB/s]
# Extracting files...
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    Male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    Male  35.0      0      0   8.0500
#
#    Embarked
# 0         3
# 1         1
# 2         3
# 3         3
# 4         3

# %%
cols_to_drop = ['Name', 'Ticket', 'Cabin', 'PassengerId']
df = df.drop(columns=[col for col in cols_to_drop if col in df.columns])

if 'Age' in df.columns:
    df['Age'] = df['Age'].fillna(df['Age'].mean())

if 'Embarked' in df.columns:
    df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

df = pd.get_dummies(df)

X = df.drop('Survived', axis=1)
y = df['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid', input_shape=(X_train.shape[1],))
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3643 - loss: 1.1167 - val_accuracy: 0.4213 - val_loss: 1.1270
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3826 - loss: 1.0876 - val_accuracy: 0.4326 - val_loss: 1.1041
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4008 - loss: 1.0604 - val_accuracy: 0.4607 - val_loss: 1.0811
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4304 - loss: 1.0343 - val_accuracy: 0.4831 - val_loss: 1.0596
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4627 - loss: 1.0094 - val_accuracy: 0.4888 - val_loss: 1.0387
# Epoch 6/20
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6011 - loss: 0.7908
# Accuracy: 0.601123571395874
